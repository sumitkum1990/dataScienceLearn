# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitkum1990/dataScienceLearn/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="cd95cf70-e525-413d-b0d9-d9e47ac5e737" data-root-id="p1053" style="display: contents;"></div>

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="e87b0664-d695-4670-babf-8579a8dbf6b1" data-root-id="p1125" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,8]

output_file("line.html")
p = figure(title = "line graph")
p.line(x,y)
show(p)
# Out:
#   <div id="fdcaaf11-4366-4367-b351-e5e05f550e13" data-root-id="p1168" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,8]

output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y)
show(p)
# Out:
#   <div id="bc006a4f-50f8-40cd-b2cb-806530dba8c3" data-root-id="p1207" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,8]

output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y, size = 20)
show(p)
# Out:
#   <div id="dd20c838-c4ef-43e5-8419-a2f08e5dd77f" data-root-id="p1246" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,8]

output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y, size = 20, color = 'red')
show(p)
# Out:
#   <div id="bfc9712e-0844-4474-8b8c-6541f93ae57a" data-root-id="p1314" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,8]

output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y, size = 20, color = 'red', legend_label ="this is my data point" )
show(p)
# Out:
#   <div id="ec2cb8b6-0e14-4490-b4c0-d33de793d9ff" data-root-id="p1353" style="display: contents;"></div>
